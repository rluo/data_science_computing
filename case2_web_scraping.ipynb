# %% [markdown]
# # Download PUMS data
# Go to https://www2.census.gov/programs-surveys/acs/data/pums/2018/5-Year/

# %%
from urllib.request import urlopen, urlretrieve
import time

# %%
url = 'https://www2.census.gov/programs-surveys/acs/data/pums/2018/5-Year/'
contents = urlopen(url).read().decode('utf-8').split('\n')

# %%
contents
# Out:
# ['<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">',
#  '<html>',
#  ' <head>',
#  '  <title>Index of /programs-surveys/acs/data/pums/2018/5-Year</title>',
#  ' </head>',
#  ' <body>',
#  '<!-- Used for CSS resets and making rendering consistent across all browsers/devices -->\r',
#  '<!-- add Universal Federated Analytics -->\r',
#  '<script language="javascript" id="_fed_an_ua_tag" src="//www.census.gov/main/javascript/federated-analytics-min.js?agency=DOC&subagency=CEN" class="global-file"></script>\r',
#  '\r',
#  '<!-- Adding original census.gov css -->\r',
#  '<link rel="stylesheet" href="//www.census.gov/main/css/_new/bootstrap.css" class="cb-main-support global-file">\r',
#  '<link rel="stylesheet" href="//www.census.gov/main/css/_new/base.css" class="cb-main-support global-file">\r',
#  '<link rel="stylesheet" href="//www.census.gov/main/css/_new/extra.css" class="cb-main-support global-file">\r',
#  '<link rel="stylesheet" href="//www.census.gov/main/css/_new/typeahead.css" class="cb-main-support global-file">\r',
#  '<link rel="stylesheet" href="//www.census.gov/main/css/_new/header.css" class="cb-main-support global-file">\r',
#  '<link rel="stylesheet" href="//www.census.gov/main/css/_new/search.css" class="cb-main-support global-file">\r',
#  '\r',
#  '<script src="//www.census.gov/main/responsive-header/jquery/jquery.js" class="cb-main-support global-file"></script>\r',
#  '<script src="//www.census.gov/main/responsive-header/jquery/jquery-ui.js" class="cb-main-support global-file"></script>\r',
#  '\r',
#  '<!-- Check for jquery conflict -->\r',
#  '<script type="text/javascript">\r',
#  '    $acn = jQuery.noConflict();\r',
#  "    if (typeof jQuery === 'undefined' || typeof $ === 'undefined') {\r",
#  '        jQuery = $acn;\r',
#  '        $ = $acn;\r',
#  '    }\r',
#  '    $(function () {\r',
#  "        $('.cb-header-skip-nav').click(function () {\r",
#  "            $('#cb-after-header-anchor').focus();\r",
#  '        });\r',
#  '    });\r',
#  '</script>\r',
#  '\r',
#  '<script src="//www.census.gov/main/responsive-header/bootstrap-custom/js/bootstrap.js" class="cb-main-support global-file"></script>\r',
#  '<script src="//www.census.gov/main/responsive-header/js/typeahead.js" class="cb-main-support global-file"></script>\r',
#  '<script src="//www.census.gov/main/javascript/clickjack.js" class="cb-main-support global-file"></script>\r',
#  '\r',
#  '<!-- Adding DTM --> \r',
#  '<script src="//assets.adobedtm.com/526d5084b7f8f688ea81a3aba09755d76a81f8e8/satelliteLib-5b0c69cba9998404374755048324ea6deb6c9db5.js"></script>\r',
#  '<script type="text/javascript">\r',
#  '\r',
#  'var digitalData = digitalData || {};\r',
#  '  digitalData = {\r',
#  '      "page" : {\r',
#  '          "pageInfo" : {                \r',
#  '              "pageName"       : "Census.gov_166506",\r',
#  '              "legacyPageName" : "Census.gov",\r',
#  '              "pageURL"        : window.location.href,\r',
#  '              "language"       : "en",\r',
#  '              "pageTemplate"   : "DPL",\r',
#  '              "tool"           : "aem",\r',
#  '              "siteSection"    : "Census Home"\r',
#  '          },\r',
#  '          "pageTag" : {\r',
#  '                             \r',
#  '              \r',
#  '          }\r',
#  '      },\r',
#  '      "event" : {\r',
#  '        "eventName" : {},\r',
#  '        "eventInfo" : {\r',
#  '          "share" : {},\r',
#  '          "download" : {},\r',
#  '          "search" : {},\r',
#  '          "expandCollapseList" : {},\r',
#  '          "language" : {},\r',
#  '          "landingPageTab" : {}\r',
#  '        }\r',
#  '      }\r',
#  '  };\r',
#  '\r',
#  '  if ( typeof(Storage) !== "undefined" ) {\r',
#  '    if ( localStorage.getItem("pageLanguage") != null ) {\r',
#  '      digitalData.event.eventInfo.language.pageLanguage = localStorage.getItem("pageLanguage");\r',
#  '    }\r',
#  '    if ( localStorage.getItem("langEventName") != null ) {\r',
#  '      digitalData.event.eventName = localStorage.getItem("langEventName");\r',
#  '    }\r',
#  '    if ( localStorage.getItem("clickValue") != null ) {\r',
#  '      digitalData.event.eventInfo.search.clickValue = localStorage.getItem("clickValue");\r',
#  '    }\r',
#  '    if ( localStorage.getItem("searchEventName") != null ) {\r',
#  '      digitalData.event.eventName = localStorage.getItem("searchEventName");\r',
#  '    }\r',
#  '    /*if ( localStorage.getItem("landingPageTabClickValue") != null ) {\r',
#  '      digitalData.event.eventInfo.landingPageTab.clickValue = localStorage.getItem("landingPageTabClickValue");\r',
#  '    }*/ \r',
#  '    if ( localStorage.getItem("tabEventName") != null ) {\r',
#  '      digitalData.event.eventName = localStorage.getItem("tabEventName");\r',
#  '    } \r',
#  '    if ( localStorage.getItem("pageName") != null ) {\r',
#  '      digitalData.page.pageInfo.pageName = localStorage.getItem("pageName");\r',
#  '    }       \r',
#  "    //After assigning the value to digitalData, clear the localStorage variable's content\r",
#  '    localStorage.removeItem("pageLanguage");\r',
#  '    localStorage.removeItem("langEventName");\r',
#  '    localStorage.removeItem("clickValue");\r',
#  '    localStorage.removeItem("searchEventName");\r',
#  '    localStorage.removeItem("landingPageTabClickValue");\r',
#  '    localStorage.removeItem("tabEventName");\r',
#  '    localStorage.removeItem("pageName");\r',
#  '  } else {\r',
#  '    if ( getCookie("pageLanguage") != "" ) {\r',
#  '      digitalData.event.eventInfo.language.pageLanguage = getCookie("pageLanguage");\r',
#  '    }\r',
#  '    if ( getCookie("langEventName") != "" ) {\r',
#  '      digitalData.event.eventName = getCookie("langEventName");\r',
#  '    }\r',
#  '    if ( getCookie("clickValue") != "" ) {\r',
#  '      digitalData.event.eventInfo.search.clickValue = getCookie("clickValue");\r',
#  '    }\r',
#  '    if ( getCookie("searchEventName") != "" ) {\r',
#  '      digitalData.event.eventName = getCookie("searchEventName");\r',
#  '    }\r',
#  '    if ( getCookie("landingPageTabClickValue") != "" ) {\r',
#  '      digitalData.event.eventInfo.landingPageTab.clickValue = getCookie("landingPageTabClickValue");\r',
#  '    }\r',
#  '    if ( getCookie("tabEventName") != "" ) {\r',
#  '      digitalData.event.eventName = getCookie("tabEventName");\r',
#  '    }\r',
#  '    if ( getCookie("pageName") != "" ) {\r',
#  '      digitalData.page.pageInfo.pageName = getCookie("pageName");\r',
#  '    }\r',
#  "    //After assigning the value to digitalData, clear the localStorage variable's content\r",
#  '    setCookie("pageLanguage", "");\r',
#  '    setCookie("langEventName", "");\r',
#  '    setCookie("clickValue", "");\r',
#  '    setCookie("searchEventName", "");\r',
#  '    setCookie("landingPageTabClickValue", "");\r',
#  '    setCookie("pageName", "");\r',
#  '  }\r',
#  '\r',
#  '  function setCookie(cname, cvalue, exdays) {\r',
#  '     var d = new Date();\r',
#  '     d.setTime(d.getTime() + (exdays*24*60*60*1000));\r',
#  '     var expires = "expires="+d.toUTCString();\r',
#  '     document.cookie = cname + "=" + cvalue + ";" + expires + ";path=/";\r',
#  '  }\r',
#  '\r',
#  '  function getCookie(cname) {\r',
#  '     var name = cname + "=";\r',
#  "     var ca = document.cookie.split(';');\r",
#  '     for(var i = 0; i < ca.length; i++) {\r',
#  '         var c = ca[i];\r',
#  "         while (c.charAt(0) == ' ') {\r",
#  '             c = c.substring(1);\r',
#  '         }\r',
#  '         if (c.indexOf(name) == 0) {\r',
#  '             return c.substring(name.length, c.length);\r',
#  '         }\r',
#  '     }\r',
#  '     return "";\r',
#  '  }\r',
#  '</script>\r',
#  '\r',
#  '\r',
#  '<style type="text/css">\r',
#  '  header.hdr-primary,\r',
#  '  header.hdr-primary > nav {\r',
#  '    display: flex !important;\r',
#  '    align-items: center !important;\r',
#  '    margin: 0 !important;\r',
#  '    padding: 0 !important;\r',
#  '    height: 64px !important;\r',
#  '    background-color: #112e51 !important;\r',
#  '    border-color: #112e51 !important;\r',
#  '  }\r',
#  '  header.hdr-primary > nav > div {\r',
#  '    box-sizing: border-box !important;\r',
#  '    height: 36.62px !important;\r',
#  '    font-size: 20px !important;\r',
#  '    font-weight: 500 !important;\r',
#  '    letter-spacing: 0.02em !important;\r',
#  '    line-height: 30px !important;\r',
#  '    white-space: nowrap !important;\r',
#  '    vertical-align: baseline !important;\r',
#  '    padding: 0 0 0 16px !important;\r',
#  '    margin: 0 !important;\r',
#  '    min-width: 150px !important;\r',
#  '  }\r',
#  '  header.hdr-primary > nav > div > a,\r',
#  '  header.hdr-primary > nav > div > a > img {\r',
#  '    padding: 0 !important;\r',
#  '    margin: 0 !important;\r',
#  '    border-style: none !important;\r',
#  '    background: transparent !important;\r',
#  '    text-decoration: none !important;\r',
#  '  }\r',
#  '  header.hdr-primary > nav > div > a {  \r',
#  '    box-sizing: border-box !important;\r',
#  '    cursor: pointer !important;\r',
#  '    text-decoration: none !important;\r',
#  '  }\r',
#  '  header.hdr-primary > nav > div > a > img {\r',
#  '    width: 86px !important;\r',
#  '    height: 33.62px !important;\r',
#  '    margin-left: 15px !important;\r',
#  '  }\r',
#  '</style>\r',
#  '<button class="cb-header-skip-nav sr-only sr-only-focusable">Skip to main content</button>\r',
#  '<header class="hdr-primary">\r',
#  '  <nav>\r',
#  '    <div><a href="//www.census.gov" id="census-home-link"><img src="//data.census.gov/cedsci/img/census-logo-white.25c8cb29.svg" alt="United States Census Bureau" title="U.S. Census Bureau"></a></div>\r',
#  '  </nav>\r',
#  '</header>\r',
#  '<a class="sr-only" tabindex="-1" id="cb-after-header-anchor">end of header</a>\r',
</td><td>&nbsp;</td></tr>',
#  '<tr><td valign="top"><img src="/icons/compressed.gif" alt="[   ]"></td><td><a href="unix_pga.zip">unix_pga.zip</a></td><td align="right">17-Dec-2019 11:19  </td><td align="right"> 73M</td><td>&nbsp;</td></tr>',
#  '<tr><td valign="top"><img src="/icons/compressed.gif" alt="[   ]"></td><td><a href="unix_phi.zip">unix_phi.zip</a></td><td align="right">17-Dec-2019 11:18  </td><td align="right"> 11M</td><td>&nbsp;</td></tr>',
#  '<tr><td valign="top"><img src="/icons/compressed.gif" alt="[   ]"></td><td><a href="unix_pia.zip">unix_pia.zip</a></td><td align="right">17-Dec-2019 11:18  </td><td align="right"> 23M</td><td>&nbsp;</td></tr>',
#  '<tr><td valign="top"><img src="/icons/compressed.gif" alt="[   ]"></td><td><a href="unix_pid.zip">unix_pid.zip</a></td><td align="right">17-Dec-2019 11:17  </td><td align="right"> 12M</td><td>&nbsp;</td></tr>',
#  '<tr><td valign="top"><img src="/icons/compressed.gif" alt="[   ]"></td><td><a href="unix_pil.zip">unix_pil.zip</a></td><td align="right">17-Dec-2019 11:17  </td><td align="right"> 92M</td><td>&nbsp;</td></tr>',
#  '<tr><td valign="top"><img src="/icons/compressed.gif" alt="[   ]"></td><td><a href="unix_pin.zip">unix_pin.zip</a></td><td align="right">17-Dec-2019 11:15  </td><td align="right"> 49M</td><td>&nbsp;</td></tr>',
#  '<tr><td valign="top"><img src="/icons/compressed.gif" alt="[   ]"></td><td><a href="unix_pks.zip">unix_pks.zip</a></td><td align="right">17-Dec-2019 11:15  </td><td align="right"> 21M</td><td>&nbsp;</td></tr>',
#  '<tr><td valign="top"><img src="/icons/compressed.gif" alt="[   ]"></td><td><a href="unix_pky.zip">unix_pky.zip</a></td><td align="right">17-Dec-2019 11:14  </td><td align="right"> 33M</td><td>&nbsp;</td></tr>',
#  '<tr><td valign="top"><img src="/icons/compressed.gif" alt="[   ]"></td><td><a href="unix_pla.zip">unix_pla.zip</a></td><td align="right">17-Dec-2019 11:14  </td><td align="right"> 33M</td><td>&nbsp;</td></tr>',
# ...
#  '                        </li>\r',
#  '                    </ul>\r',
#  '\r',
#  '                </div>\r',
#  '            </div>\r',
#  '            <div class="col-lg-2">\r',
#  '                <div class="foot_col">\r',
#  '                    <ul class="list-unstyled">\r',
#  '                        <!--FIND DATA-->\r',
#  '                        <li class="foot_col_headers">FIND DATA</li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/data/data-tools/quickfacts.html">QuickFacts</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/data/data-tools/american-factfinder.html">American\r',
#  '                                FactFinder</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/programs-surveys/decennial-census/2010-census.html">2010\r',
#  '                                Census</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/programs-surveys/economic-census.html">Economic Census</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/geography/interactive-maps.html">Interactive Maps</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/data/training-workshops.html">Training &amp; Workshops</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/data/data-tools.html">Data Tools</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/developers/">Developers</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/data/product-catalog.html">Catalogs</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/library/publications.html">Publications</a>\r',
#  '                        </li>\r',
#  '                    </ul>\r',
#  '\r',
#  '                </div>\r',
#  '            </div>\r',
#  '            <div class="col-lg-2">\r',
#  '                <div class="foot_col">\r',
#  '                    <ul class="list-unstyled">\r',
#  '                        <!--BUSINESS & INDUSTRY-->\r',
#  '                        <li class="foot_col_headers">BUSINESS &amp; INDUSTRY</li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/business/business-help.html">Help With Your\r',
#  '                                Forms</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/economy/economic-indicators.html">Economic\r',
#  '                                Indicators</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/programs-surveys/economic-census.html">Economic Census</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/programs-surveys/e-stats.html">E-Stats</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/international-trade.html">International\r',
#  '                                Trade</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/international-trade/schedule-b.html">Export Codes</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/economy/classification-codes.html">NAICS</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/public-sector.html">Governments</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/employment/led.html">Longitudinal\r',
#  '                                Employer-Household Dynamics (LEHD)</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/programs-surveys/sbo.html">Survey of\r',
#  '                                Business Owners</a>\r',
#  '                        </li>\r',
#  '                    </ul>\r',
#  '\r',
#  '                </div>\r',
#  '            </div>\r',
#  '            <div class="col-lg-2">\r',
#  '                <div class="foot_col">\r',
#  '                    <ul class="list-unstyled">\r',
#  '                        <!--PEOPLE & HOUSEHOLDS-->\r',
#  '                        <li class="foot_col_headers">PEOPLE &amp; HOUSEHOLDS</li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/2020census/">2020 Census</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/programs-surveys/decennial-census/2010-census.html/">2010\r',
#  '                                Census</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/programs-surveys/acs/">American\r',
#  '                                Community <br/>Survey</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/income-poverty/income.html">Income</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/income-poverty/poverty.html">Poverty</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/population/population-estimates.html">Population\r',
#  '                                Estimates</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/population/population-projections.html">Population\r',
#  '                                Projections</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/health/health-insurance.html">Health Insurance</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/housing.html">Housing</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/population/international.html">International</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/population/genealogy.html">Genealogy</a>\r',
#  '                        </li>\r',
#  '                    </ul>\r',
#  '                </div>\r',
#  '            </div>\r',
#  '            <div class="col-lg-2">\r',
#  '                <div class="foot_col">\r',
#  '                    <ul class="list-unstyled">\r',
#  '                        <!--SPECIAL TOPICS-->\r',
#  '                        <li class="foot_col_headers">SPECIAL TOPICS</li>\r',
#  '\r',
#  '                        <li style="padding-bottom:5px;line-height:normal">\r',
#  '                            <a href="//www.census.gov/about/partners.html">Advisors, Centers and Research Programs</a>\r',
#  '                        </li>\r',
#  '\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/schools/">Statistics in Schools</a>\r',
#  '                        </li>\r',
#  '\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/about/cong-gov-affairs/intergovernmental-affairs/tribal-affairs/tribal-resources.html">Tribal\r',
#  '                                Resources (AIAN)</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/topics/preparedness.html">Emergency Preparedness</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/library/publications/time-series/statistical_abstracts.html">Statistical\r',
#  '                                Abstract</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/programs-surveys/specialcensus.html">Special Census Program</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/datalinkage">Data Linkage Infrastructure</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/programs-surveys/are-you-in-a-survey/fraudulent-activity-and-scams.html">Fraudulent\r',
#  '                                Activity &amp; Scams</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.usa.gov/">USA.gov</a>\r',
#  '                        </li>\r',
#  '                    </ul>\r',
#  '\r',
#  '                </div>\r',
#  '\r',
#  '            </div>\r',
#  '            <div class="col-lg-2">\r',
#  '                <div class="foot_col">\r',
#  '                    <ul class="list-unstyled">\r',
#  '                        <!--NEWSROOM-->\r',
#  '                        <li class="foot_col_headers"><a\r',
#  '                                href="//www.census.gov/newsroom.html">NEWSROOM</a></li>\r',
#  '\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/newsroom/press-releases.html">News Releases</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.calendarwiz.com/calendars/calendar.php?crd=cens1sample&amp;cid[]=31793">Release\r',
#  '                                Schedule</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/newsroom/facts-for-features.html">Facts for\r',
#  '                                Features</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/newsroom/stories.html">Stats for Stories</a>\r',
#  '                        </li>\r',
#  '                        <li class="foot_col_link">\r',
#  '                            <a href="//www.census.gov/about/contact-us/social_media.html">Blogs</a>\r',
#  '                        </li>\r',
#  '                    </ul>\r',
#  '\r',
#  '                </div>\r',
#  '            </div>\r',
#  '        </div>\r',
#  '\r',
#  '        <div class="foot_bottom">\r',
#  '            <div class="foot_bottom_links">\r',
#  '                <div class="footerbottom">\r',
#  '\t\t\t\t\t\t\t<span style="font: bold x-small Arial, Verdana, sans-serif; color: rgb(231, 240, 244);"><a\r',
#  '                                    class="foot_bottom_socialLinks"\r',
#  '                                    href="//www.census.gov/about/contact-us/social_media.html">CONNECT WITH US</a></span>\r',
#  '\r',
#  '                    <a class="foot_bottom_socialLinks"\r',
#  '                       href="//www.facebook.com/uscensusbureau" target="_blank">\r',
#  '                        <img src="//www.census.gov/main/img/Facebook_White.svg"\r',
#  '                             alt="Facebook logo" title="Facebook" style="padding-right: 3px; padding-left:3px;"/></a>\r',
#  '\r',
#  '                    <a class="foot_bottom_socialLinks"\r',
#  '                       href="//twitter.com/uscensusbureau" target="_blank">\r',
#  '                        <img src="//www.census.gov/main/img/Twitter_White.svg"\r',
#  '                             alt="Twitter logo" title="Twitter" style="padding-right: 3px"/></a>\r',
#  '\r',
#  '                    <a class="foot_bottom_socialLinks"\r',
#  '                       href="//www.linkedin.com/company/us-census-bureau" target="_blank">\r',
#  '                        <img src="//www.census.gov/main/img/LinkedIN_White.svg"\r',
#  '                             alt="LinkedIn logo" title="LinkedIn" style="padding-right: 3px"/></a>\r',
#  '\r',
#  '                    <a class="foot_bottom_socialLinks"\r',
#  '                       href="//www.youtube.com/user/uscensusbureau" target="_blank">\r',
#  '                        <img src="//www.census.gov/main/img/Youtube_White.svg"\r',
#  '                             alt="YouTube logo" title="YouTube" style="padding-right: 3px"/></a>\r',
#  '\r',
#  '                    <a class="foot_bottom_socialLinks"\r',
#  '                       href="//www.instagram.com/uscensusbureau/" target="_blank">\r',
#  '                        <img src="//www.census.gov/main/img/Instagram_White.svg"\r',
#  '                             alt="Instagram logo" title="Instagram" style="padding-right: 3px"/></a>\r',
#  '\r',
#  '                    <a class="foot_bottom_socialLinks"\r',
#  '                       href="//public.govdelivery.com/accounts/USCENSUS/subscriber/new" target="_blank">\r',
#  '                        <img src="//www.census.gov/main/img/Mail_White.svg"\r',
#  '                             alt="Email Updates logo" title="Email Updates" style="padding-right: 3px"/></a>\r',
#  '                    <ul class="legal-menu">\r',
#  '                        <li>\r',
#  '                            <a href="//www.census.gov/about/policies/privacy/privacy-policy.html#par_textimage_1">Accessibility</a>\r',
#  '                        </li>\r',
#  '                        <li>\r',
#  '                            <a href="//www.census.gov/quality/">Information Quality</a>\r',
#  '                        </li>\r',
#  '                        <li>\r',
#  '                            <a href="//www.census.gov/foia/">FOIA</a>\r',
#  '                        </li>\r',
#  '                        <li>\r',
#  '                            <a href="//www.census.gov/privacy/">Data Protection and Privacy Policy</a>\r',
#  '                        </li>\r',
#  '                        <li>\r',
#  '                            <a href="//www.commerce.gov/">U.S. Department of Commerce</a>\r',
#  '                        </li>\r',
#  '\r',
#  '                    </ul>\r',
#  '\r',
#  '                </div> <!-- end class=footerbotom -->\r',
#  '            </div> <!-- end class=foot_bottom_links -->\r',
#  '        </div> <!-- end class=grid_footer_links -->\r',
#  '    </div>\r',
#  '</footer> <!-- end class=footer -->\r',
#  '\r',
#  '</body></html>',
#  '']

# %%
csv_names = [line[84:95] for line in contents if 'csv' in line]

# %%
csv_names
# Out:
# ['csv_hak.zip',
#  'csv_hal.zip',
#  'csv_har.zip',
#  'csv_haz.zip',
#  'csv_hca.zip',
#  'csv_hco.zip',
#  'csv_hct.zip',
#  'csv_hdc.zip',
#  'csv_hde.zip',
#  'csv_hfl.zip',
#  'csv_hga.zip',
#  'csv_hhi.zip',
#  'csv_hia.zip',
#  'csv_hid.zip',
#  'csv_hil.zip',
#  'csv_hin.zip',
#  'csv_hks.zip',
#  'csv_hky.zip',
#  'csv_hla.zip',
#  'csv_hma.zip',
#  'csv_hmd.zip',
#  'csv_hme.zip',
#  'csv_hmi.zip',
#  'csv_hmn.zip',
#  'csv_hmo.zip',
#  'csv_hms.zip',
#  'csv_hmt.zip',
#  'csv_hnc.zip',
#  'csv_hnd.zip',
#  'csv_hne.zip',
#  'csv_hnh.zip',
#  'csv_hnj.zip',
#  'csv_hnm.zip',
#  'csv_hnv.zip',
#  'csv_hny.zip',
#  'csv_hoh.zip',
#  'csv_hok.zip',
#  'csv_hor.zip',
#  'csv_hpa.zip',
#  'csv_hpr.zip',
#  'csv_hri.zip',
#  'csv_hsc.zip',
#  'csv_hsd.zip',
#  'csv_htn.zip',
#  'csv_htx.zip',
#  'csv_hus.zip',
#  'csv_hut.zip',
#  'csv_hva.zip',
#  'csv_hvt.zip',
#  'csv_hwa.zip',
#  'csv_hwi.zip',
#  'csv_hwv.zip',
#  'csv_hwy.zip',
#  'csv_pak.zip',
#  'csv_pal.zip',
#  'csv_par.zip',
#  'csv_paz.zip',
#  'csv_pca.zip',
#  'csv_pco.zip',
#  'csv_pct.zip',
#  'csv_pdc.zip',
#  'csv_pde.zip',
#  'csv_pfl.zip',
#  'csv_pga.zip',
#  'csv_phi.zip',
#  'csv_pia.zip',
#  'csv_pid.zip',
#  'csv_pil.zip',
#  'csv_pin.zip',
#  'csv_pks.zip',
#  'csv_pky.zip',
#  'csv_pla.zip',
#  'csv_pma.zip',
#  'csv_pmd.zip',
#  'csv_pme.zip',
#  'csv_pmi.zip',
#  'csv_pmn.zip',
#  'csv_pmo.zip',
#  'csv_pms.zip',
#  'csv_pmt.zip',
#  'csv_pnc.zip',
#  'csv_pnd.zip',
#  'csv_pne.zip',
#  'csv_pnh.zip',
#  'csv_pnj.zip',
#  'csv_pnm.zip',
#  'csv_pnv.zip',
#  'csv_pny.zip',
#  'csv_poh.zip',
#  'csv_pok.zip',
#  'csv_por.zip',
#  'csv_ppa.zip',
#  'csv_ppr.zip',
#  'csv_pri.zip',
#  'csv_psc.zip',
#  'csv_psd.zip',
#  'csv_ptn.zip',
#  'csv_ptx.zip',
#  'csv_pus.zip',
#  'csv_put.zip',
#  'csv_pva.zip',
#  'csv_pvt.zip',
#  'csv_pwa.zip',
#  'csv_pwi.zip',
#  'csv_pwv.zip',
#  'csv_pwy.zip']

# %%
# Download the files automatically
for csv_name in csv_names:
    print("Downloading %s" % csv_name)
    urlretrieve(url + csv_name, csv_name)
    # To avoid overwhelming the web traffic,
    # add pauses between downloads to human clicking.
    time.sleep(10)
# Out:
# Downloading csv_hak.zip
# Downloading csv_hal.zip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-377dc908c618> in <module>
#       2 for csv_name in csv_names:
#       3     print("Downloading %s" % csv_name)
# ----> 4     urlretrieve(url + csv_name, csv_name)
#       5     # To avoid overwhelming the web traffic,
#       6     # add pauses between downloads to human clicking.
#
# ~/anaconda3/envs/pyr/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     274
#     275             while True:
# --> 276                 block = fp.read(bs)
#     277                 if not block:
#     278                     break
#
# ~/anaconda3/envs/pyr/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/anaconda3/envs/pyr/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/anaconda3/envs/pyr/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~/anaconda3/envs/pyr/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~/anaconda3/envs/pyr/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~/anaconda3/envs/pyr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/envs/pyr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/envs/pyr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Download Yahoo Stock Data

# %%
from urllib.request import urlretrieve
import time
import random
from selenium import webdriver
from selenium.webdriver.common.by import By


# Try the standard way for downloading webpages
url = "https://finance.yahoo.com/quote/XOM/history?p=XOM"
urlretrieve(url, 'output2.html')

# Selenium
chrome_options = webdriver.ChromeOptions()
chrome_options.add_experimental_option('prefs', {
    "profile.default_content_settings.popups": 0,
    "download.prompt_for_download": False,
    "download.default_directory": "/Users/xluo/Downloads/"
})
driver = webdriver.Chrome(options=chrome_options)


driver.get("https://finance.yahoo.com/quote/XOM/history?p=XOM")
time.sleep(10)

# %%
hp_csv = driver.find_element(By.XPATH, "//a[contains(@download, 'csv')]")

# %%
hp_csv.click()

# %%
driver.close()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386         else:
# --> 387             conn.request(method, url, **httplib_request_kw)
#     388
#
# ~/anaconda3/envs/pyr/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# ~/anaconda3/envs/pyr/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# ~/anaconda3/envs/pyr/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1238             raise CannotSendHeader()
# -> 1239         self._send_output(message_body, encode_chunked=encode_chunked)
#    1240
#
# ~/anaconda3/envs/pyr/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/anaconda3/envs/pyr/lib/python3.7/http/client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     183     def connect(self):
# --> 184         conn = self._new_conn()
#     185         self._prepare_conn(conn)
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e
#     170             )
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x10aad1090>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-27-ad0c9a213c39> in <module>
# ----> 1 driver.close()
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in close(self)
#     686             driver.close()
#     687         """
# --> 688         self.execute(Command.CLOSE)
#     689
#     690     def quit(self):
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      74         if method in self._encode_url_methods:
#      75             return self.request_encode_url(
# ---> 76                 method, url, fields=fields, headers=headers, **urlopen_kw
#      77             )
#      78         else:
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      95             url += "?" + urlencode(fields)
#      96
# ---> 97         return self.urlopen(method, url, **extra_kw)
#      98
#      99     def request_encode_body(
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     328             response = conn.urlopen(method, url, **kw)
#     329         else:
# --> 330             response = conn.urlopen(method, u.request_uri, **kw)
#     331
#     332         redirect_location = redirect and response.get_redirect_location()
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     758                 chunked=chunked,
#     759                 body_pos=body_pos,
# --> 760                 **response_kw
#     761             )
#     762
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     758                 chunked=chunked,
#     759                 body_pos=body_pos,
# --> 760                 **response_kw
#     761             )
#     762
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     758                 chunked=chunked,
#     759                 body_pos=body_pos,
# --> 760                 **response_kw
#     761             )
#     762
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     718
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#     722             retries.sleep()
#
# ~/anaconda3/envs/pyr/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     434
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#     438         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=50452): Max retries exceeded with url: /session/7fe2af01a2bfbc60ab5e1fc2c4fc6fbe/window (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10aad1090>: Failed to establish a new connection: [Errno 61] Connection refused'))
